# %% [markdown]
# <a href="https://colab.research.google.com/github/yangkong2/NVDIA_yolo/blob/main/1%ED%95%99%EA%B8%B0%EC%A4%91%EA%B0%84%EA%B3%A0%EC%82%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ultralytics 라이브러리 설치 (YOLOv8을 사용하려면 필요해요)
# !pip install ultralytics -q

# ultralytics에서 제공하는 yolov8x 모델 자동 다운로드
from ultralytics import YOLO

# yolov8x 모델을 불러오면 자동으로 다운로드돼요
model = YOLO('yolov8x.pt')

print("yolov8x.pt 모델 다운로드 완료!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
from google.colab import files

# 파일 업로드창이 열려요
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8fd7df8a-98d7-42a6-a7fc-a3f7eb226fdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fd7df8a-98d7-42a6-a7fc-a3f7eb226fdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# /content 폴더 안에 있는 파일 리스트 보여줌
for file in os.listdir('/content'):
    print(file)
# Out:
# .config
# yolov8x.pt
# yolo.png
# sample_data

# %%
results = model('yolo.png')   # 결과는 리스트
results[0].show()               # 첫 번째 결과 객체를 꺼내서 시각화
# Out:
# image 1/1 /content/yolo.png: 640x352 9 cats, 9 dogs, 63.3ms
# Speed: 14.0ms preprocess, 63.3ms inference, 356.4ms postprocess per image at shape (1, 3, 640, 352)
# <PIL.Image.Image image mode=RGB size=624x1207>
